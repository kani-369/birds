# %%
import torch 
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
from google.colab import drive 
drive.mount('/content/drive')

# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# Mounted at /content/drive

# %%
# !kaggle competitions download -c birdclef-2026
# !unzip birdclef-2026.zip -d /content/
# Out:
# birdclef-2026.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  birdclef-2026.zip
# replace /content/recording_location.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !find /content -name "train.py"
# Out:
# /content/drive/MyDrive/birdclef_fullles/train.py

# %%
# %cd /content/drive/MyDrive/birdclef_fullles
# Out:
# /content/drive/MyDrive/birdclef_fullles

# %%
# !ls
# Out:
# bird_cliff.zip	  recording_location.txt  train_audio
# data_pipeline.py  sample_submission.csv   train.csv
# dataset.py	  taxonomy.csv		  train.py
# model.py	  test_pipeline.py	  train_soundscapes
# __pycache__	  test_soundscapes	  train_soundscapes_labels.csv

# %%
# !python train.py
# Out:
# Run directory created: /content/drive/MyDrive/birdclef_models/run_1777621859
# Starting Training Execution (Level-3 Safety)...
# Error: /content/train_metadata.csv not found. Please ensure your dataset is placed here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python train.py
# Out:
# Run directory created: /content/drive/MyDrive/birdclef_models/run_1777622174
# Starting Training Execution (Level-3 Safety)...
# Number of species: 206
# Using device: cuda
#
# Starting Training...
#
# ⚠️ Training ended or interrupted → Saving final state...
# ✅ Full checkpoint saved → /content/drive/MyDrive/birdclef_models/run_1777622174/final_model.pth
# Training Loop Terminated Successfully.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/birdclef_fullles/train.py", line 187, in <module>
#     main()
#   File "/content/drive/MyDrive/birdclef_fullles/train.py", line 133, in main
#     for batch in train_loader:
#                  ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 741, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 801, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 54, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "/content/drive/MyDrive/birdclef_fullles/dataset.py", line 70, in __getitem__
#     spectrograms = process_audio(audio_path)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/birdclef_fullles/data_pipeline.py", line 41, in process_audio
#     y, sr = librosa.load(file_path, sr=sr)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/librosa/core/audio.py", line 176, in load
#     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/librosa/core/audio.py", line 222, in __soundfile_load
#     y = sf_desc.read(frames=frame_duration, dtype=dtype, always_2d=False).T
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/soundfile.py", line 942, in read
#     frames = self._array_io('read', out, frames)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/soundfile.py", line 1394, in _array_io
#     return self._cdata_io(action, cdata, ctype, frames)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/soundfile.py", line 1403, in _cdata_io
#     frames = func(self._file, data, frames)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
